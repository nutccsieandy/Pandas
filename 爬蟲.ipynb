# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests as rt

# %%
web=rt.get('https://udb.moe.edu.tw/')
print(web.text)
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <meta charset="utf-8" />
#     <meta name="keywords" content="教育部大專校院校務資訊公開平臺">
#     <meta name="description" content="教育部大專校院校務資訊公開平臺">
#     <meta name="device" content="ng3-113">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" />
#     <meta name="Accessible_website" content="本網站通過AA檢測等級無障礙網頁檢測">
#     <title>大專校院校務資訊公開</title>
#     <title id="Head_Title">教育部大專校院校務資訊公開平臺</title>
#     <link href="/Content/Query.css" type="text/css" rel="stylesheet">
#
#     <link href="/Content/CustomizeBootstrap.css" type="text/css" rel="stylesheet">
#
#
#
#     <link href="../Content/TreeGridIMG/jquery.treegrid.css"  type="text/css" rel="stylesheet">
#
#     <link href="/Content/bootstrap.css" rel="stylesheet"/>
# <link href="/Content/bootstrap-theme.min.css" rel="stylesheet"/>
# ...
